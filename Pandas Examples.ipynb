# %%
import numpy as np
import pandas as pd

# %%
def countries(country):
    return country == 'Ukraine'

# %%
df = pd.read_csv('https://github.com/owid/covid-19-data/raw/master/public/data/owid-covid-data.csv')

# %%
df.head()
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  2020-03-13          2.0        2.0
# 1      ABW  North America    Aruba  2020-03-19          NaN        NaN
# 2      ABW  North America    Aruba  2020-03-20          4.0        2.0
# 3      ABW  North America    Aruba  2020-03-21          NaN        NaN
# 4      ABW  North America    Aruba  2020-03-22          NaN        NaN
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1               0.286           NaN         NaN                  0.0  ...
# 2               0.286           NaN         0.0                  0.0  ...
# 3               0.286           NaN         NaN                  0.0  ...
# 4               0.286           NaN         NaN                  0.0  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
pd.set_option('precision', 4)

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'tests_per_case', 'positive_rate', 'tests_units', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51371 entries, 0 to 51370
# Data columns (total 41 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         51076 non-null  object
#  1   continent                        50781 non-null  object
#  2   location                         51371 non-null  object
#  3   date                             51371 non-null  object
#  4   total_cases                      47764 non-null  float64
#  5   new_cases                        50491 non-null  float64
#  6   new_cases_smoothed               49704 non-null  float64
#  7   total_deaths                     38980 non-null  float64
#  8   new_deaths                       50491 non-null  float64
#  9   new_deaths_smoothed              49704 non-null  float64
#  10  total_cases_per_million          47505 non-null  float64
# ...

# %%
df.describe()
# Out:
#        total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# count     47764.00   50491.00            49704.00      38980.00    50491.00
# mean     132949.42    1603.14             1584.67       6054.14       44.34
# std     1331520.74   14439.06            14179.97      49004.51      370.50
# min           1.00   -8261.00             -552.00          1.00    -1918.00
# 25%         141.00       0.00                0.71         11.00        0.00
# 50%        1666.50      12.00               17.00         70.00        0.00
# 75%       16653.25     190.00              197.89        606.00        3.00
# max    40472505.00  400350.00           364659.14    1119283.00    10468.00
#
#        new_deaths_smoothed  total_cases_per_million  new_cases_per_million  \
# count             49704.00                 47505.00               50427.00
# mean                 44.43                  2446.76                  29.06
# ...

# %%
df['location'].unique()
# Out:
# array(['Aruba', 'Afghanistan', 'Angola', 'Anguilla', 'Albania', 'Andorra',
#        'United Arab Emirates', 'Argentina', 'Armenia',
#        'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan',
#        'Burundi', 'Belgium', 'Benin', 'Bonaire Sint Eustatius and Saba',
#        'Burkina Faso', 'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei', 'Bhutan', 'Botswana',
#        'Central African Republic', 'Canada', 'Switzerland', 'Chile',
#        'China', "Cote d'Ivoire", 'Cameroon',
#        'Democratic Republic of Congo', 'Congo', 'Colombia', 'Comoros',
#        'Cape Verde', 'Costa Rica', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czech Republic', 'Germany', 'Djibouti', 'Dominica',
#        'Denmark', 'Dominican Republic', 'Algeria', 'Ecuador', 'Egypt',
#        'Eritrea', 'Western Sahara', 'Spain', 'Estonia', 'Ethiopia',
# ...

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51371 entries, 0 to 51370
# Data columns (total 41 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         51076 non-null  object
#  1   continent                        50781 non-null  object
#  2   location                         51371 non-null  object
#  3   date                             51371 non-null  datetime64[ns]
#  4   total_cases                      47764 non-null  float64
#  5   new_cases                        50491 non-null  float64
#  6   new_cases_smoothed               49704 non-null  float64
#  7   total_deaths                     38980 non-null  float64
#  8   new_deaths                       50491 non-null  float64
#  9   new_deaths_smoothed              49704 non-null  float64
#  10  total_cases_per_million          47505 non-null  float64
# ...

# %%
df['location'].value_counts()

# %%
df.sort_values(by=['total_cases', 'new_cases'], ascending=[False, True])
# Out:
#        iso_code continent      location       date  total_cases  new_cases  \
# 51075  OWID_WRL       NaN         World 2020-10-20  40472505.00  319434.00
# 51074  OWID_WRL       NaN         World 2020-10-19  40153071.00  358683.00
# 51073  OWID_WRL       NaN         World 2020-10-18  39794388.00  364484.00
# 51072  OWID_WRL       NaN         World 2020-10-17  39429904.00  392119.00
# 51071  OWID_WRL       NaN         World 2020-10-16  39037785.00  400350.00
# ...         ...       ...           ...        ...          ...        ...
# 50119       ZAF    Africa  South Africa 2020-03-03          nan        nan
# 50120       ZAF    Africa  South Africa 2020-03-04          nan        nan
# 50121       ZAF    Africa  South Africa 2020-03-05          nan        nan
# 50123       ZAF    Africa  South Africa 2020-03-07          nan        nan
# 50127       ZAF    Africa  South Africa 2020-03-11          nan        nan
#
# ...

# %%
df[0:5]
# Out:
#   iso_code      continent location       date  total_cases  new_cases  \
# 0      ABW  North America    Aruba 2020-03-13         2.00       2.00
# 1      ABW  North America    Aruba 2020-03-19          nan        nan
# 2      ABW  North America    Aruba 2020-03-20         4.00       2.00
# 3      ABW  North America    Aruba 2020-03-21          nan        nan
# 4      ABW  North America    Aruba 2020-03-22          nan        nan
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 nan           nan        0.00                  nan  ...
# 1                0.29           nan         nan                 0.00  ...
# 2                0.29           nan        0.00                 0.00  ...
# 3                0.29           nan         nan                 0.00  ...
# 4                0.29           nan         nan                 0.00  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
df.loc[0:5]
# Out:
#   iso_code      continent location       date  total_cases  new_cases  \
# 0      ABW  North America    Aruba 2020-03-13         2.00       2.00
# 1      ABW  North America    Aruba 2020-03-19          nan        nan
# 2      ABW  North America    Aruba 2020-03-20         4.00       2.00
# 3      ABW  North America    Aruba 2020-03-21          nan        nan
# 4      ABW  North America    Aruba 2020-03-22          nan        nan
# 5      ABW  North America    Aruba 2020-03-23          nan        nan
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 nan           nan        0.00                  nan  ...
# 1                0.29           nan         nan                 0.00  ...
# 2                0.29           nan        0.00                 0.00  ...
# 3                0.29           nan         nan                 0.00  ...
# 4                0.29           nan         nan                 0.00  ...
# ...

# %%
df[0:5][['location', 'date','total_cases']]
# Out:
#   location       date  total_cases
# 0    Aruba 2020-03-13         2.00
# 1    Aruba 2020-03-19          nan
# 2    Aruba 2020-03-20         4.00
# 3    Aruba 2020-03-21          nan
# 4    Aruba 2020-03-22          nan

# %%
df.loc[0:5, 'location':'new_deaths']
# Out:
#   location       date  total_cases  new_cases  new_cases_smoothed  \
# 0    Aruba 2020-03-13         2.00       2.00                 nan
# 1    Aruba 2020-03-19          nan        nan                0.29
# 2    Aruba 2020-03-20         4.00       2.00                0.29
# 3    Aruba 2020-03-21          nan        nan                0.29
# 4    Aruba 2020-03-22          nan        nan                0.29
# 5    Aruba 2020-03-23          nan        nan                0.29
#
#    total_deaths  new_deaths
# 0           nan        0.00
# 1           nan         nan
# 2           nan        0.00
# 3           nan         nan
# 4           nan         nan
# 5           nan         nan

# %%
df.iloc[0:5, 'location':'new_deaths']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-68b6db25f649> in <module>
# ----> 1 df.iloc[0:5, 'location':'new_deaths']
#
# C:\Python37\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# C:\Python37\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2078                 continue
#    2079
# -> 2080             retval = getattr(retval, self.name)._getitem_axis(key, axis=axis)
#    2081
#    2082             # if the dim was reduced, then pass a lower-dim the next time
#
# C:\Python37\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
# ...

# %%
df.loc[0:5, 1:4]

# %%
df.iloc[0:5, 1:4]
# Out:
#        continent location       date
# 0  North America    Aruba 2020-03-13
# 1  North America    Aruba 2020-03-19
# 2  North America    Aruba 2020-03-20
# 3  North America    Aruba 2020-03-21
# 4  North America    Aruba 2020-03-22

# %%
df.loc[:len(df), 'location':'new_deaths'].apply(np.max)
# Out:
# location                         Zimbabwe
# date                  2020-10-20 00:00:00
# total_cases                   40472505.00
# new_cases                       400350.00
# new_cases_smoothed              364659.14
# total_deaths                   1119283.00
# new_deaths                       10468.00
# dtype: object

# %%
columns_to_show = ['total_cases', 'new_cases', 'total_deaths']
df.groupby(['location'])[columns_to_show].agg([np.mean, np.std, np.min, np.max])
# Out:
#                                 total_cases                                \
#                                        mean         std  amin        amax
# location
# Afghanistan                        22562.10    16436.10  1.00    40287.00
# Albania                             4819.92     5055.55  2.00    17350.00
# Algeria                            21238.69    19267.04  1.00    54616.00
# Andorra                             1028.05      655.89  1.00     3623.00
# Angola                              1463.04     1976.61  2.00     7622.00
# Anguilla                               2.97        0.18  2.00        3.00
# Antigua and Barbuda                   59.25       36.56  1.00      119.00
# Argentina                         211218.79   283695.53  1.00  1002649.00
# Armenia                            24622.62    20083.33  1.00    65460.00
# Aruba                               1035.11     1480.52  2.00     4334.00
# ...

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
pd.options.display.float_format = '{:.2f}'.format

# %%
df.groupby(['location'])[columns_to_show].max()
# Out:
#                                  total_cases  new_cases  total_deaths
# location
# Afghanistan                         40287.00    1063.00       1497.00
# Albania                             17350.00     295.00        454.00
# Algeria                             54616.00     675.00       1865.00
# Andorra                              3623.00     299.00         62.00
# Angola                               7622.00     355.00        247.00
# Anguilla                                3.00       2.00           nan
# Antigua and Barbuda                   119.00      39.00          3.00
# Argentina                         1002649.00   17213.00      26716.00
# Armenia                             65460.00    1694.00       1091.00
# Aruba                                4334.00     176.00         34.00
# Australia                           27399.00     721.00        905.00
# Austria                             66611.00    2040.00        919.00
# ...

# %%
df[df['location'] != 'World'].groupby(['location'])[columns_to_show].max().sort_values(by='total_cases', ascending=False)

# %%
pd.options.display.min_rows=100

# %%
pd.crosstab(df['location'], df['date'])
# Out:
# date                             2019-12-31  2020-01-01  2020-01-02  \
# location
# Afghanistan                               1           1           1
# Albania                                   0           0           0
# Algeria                                   1           1           1
# Andorra                                   0           0           0
# Angola                                    0           0           0
# Anguilla                                  0           0           0
# Antigua and Barbuda                       0           0           0
# Argentina                                 0           0           0
# Armenia                                   1           1           1
# Aruba                                     0           0           0
# Australia                                 1           1           1
# Austria                                   1           1           1
# Azerbaijan                                1           1           1
# ...

# %%
df_ukraine = df[df['location'] == 'Ukraine']
df_ukraine.pivot_table(['total_cases', 'new_cases', 'total_deaths'], ['date'], aggfunc=max)
# Out:
#             new_cases  total_cases  total_deaths
# date
# 2020-03-04       1.00         1.00           nan
# 2020-03-13       2.00         3.00           nan
# 2020-03-16       0.00         3.00           nan
# 2020-03-17       2.00         5.00           nan
# 2020-03-18       9.00        14.00           nan
# 2020-03-19       5.00        19.00          2.00
# 2020-03-20       7.00        26.00          2.00
# 2020-03-21       0.00        26.00          3.00
# 2020-03-22      15.00        41.00          3.00
# 2020-03-23       6.00        47.00          3.00
# 2020-03-24      26.00        73.00          3.00
# 2020-03-25      11.00        84.00          3.00
# 2020-03-26      29.00       113.00          4.00
# 2020-03-27      43.00       156.00          5.00
# 2020-03-28      62.00       218.00          5.00
# 2020-03-29      93.00       311.00          8.00
# 2020-03-30     107.00       418.00          9.00
# 2020-03-31      62.00       480.00         11.00
# ...

# %%
df_ukraine.pivot_table(['total_cases', 'new_cases', 'total_deaths'], ['date'], aggfunc=max).fillna(0).sort_values(by='new_cases')
# Out:
#             new_cases  total_cases  total_deaths
# date
# 2020-09-17       0.00    162660.00       3340.00
# 2020-08-28       0.00    112059.00       2403.00
# 2020-03-16       0.00         3.00          0.00
# 2020-08-19       0.00     94436.00       2116.00
# 2020-10-02       0.00    208959.00       4193.00
# 2020-10-10       0.00    244734.00       4690.00
# 2020-08-15       0.00     87872.00       2011.00
# 2020-03-21       0.00        26.00          3.00
# 2020-09-12       0.00    148756.00       3076.00
# 2020-03-04       1.00         1.00          0.00
# 2020-03-17       2.00         5.00          0.00
# 2020-03-13       2.00         3.00          0.00
# 2020-03-19       5.00        19.00          2.00
# 2020-03-23       6.00        47.00          3.00
# 2020-03-20       7.00        26.00          2.00
# 2020-03-18       9.00        14.00          0.00
# 2020-03-25      11.00        84.00          3.00
# 2020-04-07      11.00      1319.00         38.00
# ...

# %%
df_ukraine.nsmallest(3, 'new_cases')
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 47352      UKR    Europe  Ukraine 2020-03-16         3.00       0.00
# 47357      UKR    Europe  Ukraine 2020-03-21        26.00       0.00
# 47504      UKR    Europe  Ukraine 2020-08-15     87872.00       0.00
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 47352                0.29           nan        0.00                 0.00  ...
# 47357                3.29          3.00        1.00                 0.43  ...
# 47504             1373.00       2011.00        0.00                22.71  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 47352         7894.39             0.10                 539.85
# 47357         7894.39             0.10                 539.85
# 47504         7894.39             0.10                 539.85
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 47352                 7.11           13.50         47.40
# ...

# %%
df_ukraine.sort_values('date', ascending=False).nsmallest(3, 'new_cases')
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 47560      UKR    Europe  Ukraine 2020-10-10    244734.00       0.00
# 47552      UKR    Europe  Ukraine 2020-10-02    208959.00       0.00
# 47537      UKR    Europe  Ukraine 2020-09-17    162660.00       0.00
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 47560             3867.57       4690.00        0.00                61.29  ...
# 47552             2979.00       4193.00       64.00                62.29  ...
# 47537             2435.43       3340.00        0.00                51.57  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 47560         7894.39             0.10                 539.85
# 47552         7894.39             0.10                 539.85
# 47537         7894.39             0.10                 539.85
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 47560                 7.11           13.50         47.40
# ...

# %%
df_ukraine.sort_values('date', ascending=False).nlargest(3, 'new_cases')
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 47561      UKR    Europe  Ukraine 2020-10-11    256266.00   11532.00
# 47569      UKR    Europe  Ukraine 2020-10-19    303638.00    9997.00
# 47553      UKR    Europe  Ukraine 2020-10-03    217661.00    8702.00
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 47561             4862.00       4887.00      197.00                76.29  ...
# 47569             6086.29       5673.00      156.00               100.14  ...
# 47553             3712.86       4261.00       68.00                62.00  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 47561         7894.39             0.10                 539.85
# 47569         7894.39             0.10                 539.85
# 47553         7894.39             0.10                 539.85
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 47561                 7.11           13.50         47.40
# ...

# %%
df_ukraine[df_ukraine['new_cases'].ne(0)].sort_values('date', ascending=False).nsmallest(3, 'new_cases')
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 47345      UKR    Europe  Ukraine 2020-03-04         1.00       1.00
# 47353      UKR    Europe  Ukraine 2020-03-17         5.00       2.00
# 47349      UKR    Europe  Ukraine 2020-03-13         3.00       2.00
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 47345                 nan           nan        0.00                  nan  ...
# 47353                0.57           nan        0.00                 0.00  ...
# 47349                0.29           nan        0.00                 0.00  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 47345         7894.39             0.10                 539.85
# 47353         7894.39             0.10                 539.85
# 47349         7894.39             0.10                 539.85
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 47345                 7.11           13.50         47.40
# ...

# %%
df_ukraine[df_ukraine['new_cases'].ne(0)].sort_values('date', ascending=False).nsmallest(3, 'new_cases').to_markdown()
# Out:
# '|       | iso_code   | continent   | location   | date                |   total_cases |   new_cases |   new_cases_smoothed |   total_deaths |   new_deaths |   new_deaths_smoothed |   total_cases_per_million |   new_cases_per_million |   new_cases_smoothed_per_million |   total_deaths_per_million |   new_deaths_per_million |   new_deaths_smoothed_per_million |   total_tests |   new_tests |   total_tests_per_thousand |   new_tests_per_thousand |   new_tests_smoothed |   new_tests_smoothed_per_thousand |   tests_per_case |   positive_rate |   tests_units |   stringency_index |   population |   population_density |   median_age |   aged_65_older |   aged_70_older |   gdp_per_capita |   extreme_poverty |   cardiovasc_death_rate |   diabetes_prevalence |   female_smokers |   male_smokers |   handwashing_facilities |   hospital_beds_per_thousand |   life_expectancy |   human_development_index |\n|------:|:-----------|:------------|:-----------|:--------------------|--------------:|--------
# ...

# %%
nan = float('nan')
print(nan)
import math
math.isnan(nan)
# Out:
# nan
# True

# %%
pd.date_range('2019-01-01', '2020-01-12', freq='W').strftime('%Y-%U')
# Out:
# Index(['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06',
#        '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12',
#        '2019-13', '2019-14', '2019-15', '2019-16', '2019-17', '2019-18',
#        '2019-19', '2019-20', '2019-21', '2019-22', '2019-23', '2019-24',
#        '2019-25', '2019-26', '2019-27', '2019-28', '2019-29', '2019-30',
#        '2019-31', '2019-32', '2019-33', '2019-34', '2019-35', '2019-36',
#        '2019-37', '2019-38', '2019-39', '2019-40', '2019-41', '2019-42',
#        '2019-43', '2019-44', '2019-45', '2019-46', '2019-47', '2019-48',
#        '2019-49', '2019-50', '2019-51', '2019-52', '2020-01', '2020-02'],
#       dtype='object')

# %%
from datetime import date
from dateutil.relativedelta import relativedelta
today = date.today()
weeks=52
[period.strftime('%Y-%U') for period in pd.period_range(start=today+relativedelta(weeks=-weeks), end=today, freq='W')]
# Out:
# ['2019-43',
#  '2019-44',
#  '2019-45',
#  '2019-46',
#  '2019-47',
#  '2019-48',
#  '2019-49',
#  '2019-50',
#  '2019-51',
#  '2019-52',
#  '2020-01',
#  '2020-02',
#  '2020-03',
#  '2020-04',
#  '2020-05',
#  '2020-06',
#  '2020-07',
#  '2020-08',
#  '2020-09',
#  '2020-10',
#  '2020-11',
#  '2020-12',
#  '2020-13',
#  '2020-14',
#  '2020-15',
#  '2020-16',
#  '2020-17',
#  '2020-18',
#  '2020-19',
#  '2020-20',
#  '2020-21',
#  '2020-22',
#  '2020-23',
#  '2020-24',
#  '2020-25',
#  '2020-26',
#  '2020-27',
#  '2020-28',
#  '2020-29',
#  '2020-30',
#  '2020-31',
#  '2020-32',
#  '2020-33',
#  '2020-34',
#  '2020-35',
#  '2020-36',
#  '2020-37',
#  '2020-38',
#  '2020-39',
#  '2020-40',
#  '2020-41',
#  '2020-42',
#  '2020-43']

# %%
[(today+relativedelta(weeks=-week)).strftime('%Y-%V') for week in range(weeks, -1, -1)]
# Out:
# ['2019-43',
#  '2019-44',
#  '2019-45',
#  '2019-46',
#  '2019-47',
#  '2019-48',
#  '2019-49',
#  '2019-50',
#  '2019-51',
#  '2019-52',
#  '2019-01',
#  '2020-02',
#  '2020-03',
#  '2020-04',
#  '2020-05',
#  '2020-06',
#  '2020-07',
#  '2020-08',
#  '2020-09',
#  '2020-10',
#  '2020-11',
#  '2020-12',
#  '2020-13',
#  '2020-14',
#  '2020-15',
#  '2020-16',
#  '2020-17',
#  '2020-18',
#  '2020-19',
#  '2020-20',
#  '2020-21',
#  '2020-22',
#  '2020-23',
#  '2020-24',
#  '2020-25',
#  '2020-26',
#  '2020-27',
#  '2020-28',
#  '2020-29',
#  '2020-30',
#  '2020-31',
#  '2020-32',
#  '2020-33',
#  '2020-34',
#  '2020-35',
#  '2020-36',
#  '2020-37',
#  '2020-38',
#  '2020-39',
#  '2020-40',
#  '2020-41',
#  '2020-42',
#  '2020-43']

# %%
#tf.to_sql('table', con=engine, if_exist='append', index=False)

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51371 entries, 0 to 51370
# Data columns (total 41 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         51076 non-null  object
#  1   continent                        50781 non-null  object
#  2   location                         51371 non-null  object
#  3   date                             51371 non-null  datetime64[ns]
#  4   total_cases                      47764 non-null  float64
#  5   new_cases                        50491 non-null  float64
#  6   new_cases_smoothed               49704 non-null  float64
#  7   total_deaths                     38980 non-null  float64
#  8   new_deaths                       50491 non-null  float64
#  9   new_deaths_smoothed              49704 non-null  float64
#  10  total_cases_per_million          47505 non-null  float64
# ...

# %%
for dtype in ['float64', 'int64', 'object']:
    selected_dtypes = df.select_dtypes(include=dtype)
    mean_usage = selected_dtypes.memory_usage(deep=True).mean()
    print(f'Average usage for {dtype}: {mean_usage} bytes')
# Out:
# Average usage for float64: 399862.54054054053 bytes
# Average usage for int64: 66.0 bytes
# Average usage for object: 1398193.2 bytes

# %%
df_float = df.select_dtypes(include='float').fillna(0)
converted_float = df_float.astype(int)

convert = lambda a: f'{(a/1024 ** 2):03.2f} MB'

print(convert(df_float.memory_usage(deep=True).sum()))
print(convert(converted_float.memory_usage(deep=True).sum()))
print(converted_float.info())
# Out:
# 14.11 MB
# 7.05 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51371 entries, 0 to 51370
# Data columns (total 36 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   total_cases                      51371 non-null  int32
#  1   new_cases                        51371 non-null  int32
#  2   new_cases_smoothed               51371 non-null  int32
#  3   total_deaths                     51371 non-null  int32
#  4   new_deaths                       51371 non-null  int32
#  5   new_deaths_smoothed              51371 non-null  int32
#  6   total_cases_per_million          51371 non-null  int32
#  7   new_cases_per_million            51371 non-null  int32
#  8   new_cases_smoothed_per_million   51371 non-null  int32
#  9   total_deaths_per_million         51371 non-null  int32
#  10  new_deaths_per_million           51371 non-null  int32
# ...

# %%
compare_types = pd.concat([df_float.dtypes, converted_float.dtypes], axis=1)
compare_types.columns = ['Було', 'Стало']
compare_types.apply(pd.Series.value_counts)
# Out:
#          Було  Стало
# int32     nan  36.00
# float64 36.00    nan

# %%
# %matplotlib inline

# %%
df_ukraine.pivot_table(['new_cases', 'new_deaths'],
                       ['date'], 
                       aggfunc=max).fillna(0).sort_values(by='new_cases').plot(kind='bar')

# %%
from matplotlib import pyplot
import seaborn
df_filtered = df_ukraine[['new_cases', 'new_deaths', 'date']]
seaborn.relplot(y='new_cases', x='date', kind='line', data=df_filtered)
pyplot.savefig('plot.png', dpi=600)

# %%
df_filtered = df_ukraine[['new_cases', 'new_deaths', 'date']][-300:]
seaborn.relplot(y='new_cases', x='date', kind='line', data=df_filtered, height=10)

# %%
df_u_pivot = df_ukraine.pivot_table(['new_cases', 'new_deaths', 'total_deaths'], ['date'], aggfunc=max)[-100:]

# %%
seaborn.relplot(kind='line', data=df_u_pivot, height=10)
